# %%
import pandas as pd

# %%
data_definition = pd.read_excel('FlightDataDescription.xlsx')

# %%
data_definition
# Out:
#               ATTRIBUTE       TYPE  \
# 0                  YEAR     Binary
# 1               FL_DATE   yyyymmdd
# 2         CARRIER_DELAY    Nominal
# 3                FL_NUM    Nominal
# 4                 ROUTE    Nominal
# 5                ORIGIN    Nominal
# 6                  DEST    Nominal
# 7             DEST_CITY    Nominal
# 8            DEST_STATE    Nominal
# 9          CRS_DEP_TIME   Interval
# 10             DEP_TIME   Interval
# 11            DEP_DELAY   Interval
# 12        DEP_DELAY_NEW   Interval
# 13            DEP_DEL15     Binary
# 14      DEP_DELAY_GROUP    Ordinal
# 15         DEP_TIME_BLK    Ordinal
# 16             TAXI_OUT   Interval
# 17           WHEELS_OFF   Interval
# 18            WHEELS_ON   Interval
# 19              TAXI_IN   Interval
# 20         CRS_ARR_TIME   Interval
# 21             ARR_TIME   Interval
# 22            ARR_DELAY   Interval
# 23        ARR_DELAY_NEW   Interval
# 24            ARR_DEL15     Binary
# ...
