# %%
##Import necessary modules

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pylab as plt 
# %matplotlib inline

# %%
df=pd.read_csv('AirlineF9.csv')

# %%
df=df.drop(columns=['Unnamed: 0'])
df
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE CARRIER  \
# 0       2018        1      1             1            1  2018-01-01      F9
# 1       2018        1      1             1            1  2018-01-01      F9
# 2       2018        1      1             2            2  2018-01-02      F9
# 3       2018        1      1             2            2  2018-01-02      F9
# 4       2018        1      1             3            3  2018-01-03      F9
# ...      ...      ...    ...           ...          ...         ...     ...
# 183118  2019        2      6            26            3  2019-06-26      F9
# 183119  2019        2      6            28            5  2019-06-28      F9
# 183120  2019        2      6            29            6  2019-06-29      F9
# 183121  2019        2      6            27            4  2019-06-27      F9
# 183122  2019        2      6            30            7  2019-06-30      F9
#
#         FL_NUM  Route ORIGIN  ... NAS_DELAY SECURITY_DELAY  \
# 0          632     19    ABQ  ...       NaN            NaN
# 1          630     19    ABQ  ...       NaN            NaN
# 2          632     19    ABQ  ...       NaN            NaN
# 3          630     19    ABQ  ...       NaN            NaN
# 4          632     19    ABQ  ...       NaN            NaN
# ...        ...    ...    ...  ...       ...            ...
# 183118     587   6588    TYS  ...       NaN            NaN
# 183119     587   6588    TYS  ...       NaN            NaN
# 183120     587   6588    TYS  ...       NaN            NaN
# 183121     219   6665    XNA  ...       6.0            0.0
# 183122     219   6665    XNA  ...      99.0            0.0
#
#        LATE_AIRCRAFT_DELAY  PASSENGERS  EMPFULL  EMPPART  EMPTOTAL  EMPFTE  \
# 0                      NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 1                      NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 2                      NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 3                      NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 4                      NaN      3461.0   3706.0     39.0    3745.0  3726.0
# ...                    ...         ...      ...      ...       ...     ...
# 183118                 NaN      2940.0   4639.0     51.0    4690.0  4665.0
# 183119                 NaN      2940.0   4639.0     51.0    4690.0  4665.0
# 183120                 NaN      2940.0   4639.0     51.0    4690.0  4665.0
# 183121                 0.0       308.0   4639.0     51.0    4690.0  4665.0
# 183122                 0.0       308.0   4639.0     51.0    4690.0  4665.0
#
#         NET_INCOME OP_REVENUES
# 0         24887.67   464436.41
# 1         24887.67   464436.41
# 2         24887.67   464436.41
# 3         24887.67   464436.41
# 4         24887.67   464436.41
# ...            ...         ...
# 183118    69809.24   593451.15
# 183119    69809.24   593451.15
# 183120    69809.24   593451.15
# 183121    69809.24   593451.15
# 183122    69809.24   593451.15
#
# [183123 rows x 50 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183123 entries, 0 to 183122
# Data columns (total 50 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 183123 non-null  int64
#  1   QUARTER              183123 non-null  int64
#  2   MONTH                183123 non-null  int64
#  3   DAY_OF_MONTH         183123 non-null  int64
#  4   DAY_OF_WEEK          183123 non-null  int64
#  5   FL_DATE              183123 non-null  object
#  6   CARRIER              183123 non-null  object
#  7   FL_NUM               183123 non-null  int64
#  8   Route                183123 non-null  int64
#  9   ORIGIN               183123 non-null  object
#  10  DEST                 183123 non-null  object
#  11  DEST_CITY            183123 non-null  object
#  12  DEST_STATE           183123 non-null  object
#  13  CRS_DEP_TIME         183123 non-null  int64
#  14  DEP_TIME             179794 non-null  float64
#  15  DEP_DELAY            179724 non-null  float64
#  16  DEP_DELAY_NEW        179724 non-null  float64
#  17  DEP_DEL15            179724 non-null  float64
#  18  DEP_DELAY_GROUP      179724 non-null  float64
#  19  DEP_TIME_BLK         183123 non-null  object
#  20  TAXI_OUT             179615 non-null  float64
#  21  WHEELS_OFF           179616 non-null  float64
#  22  WHEELS_ON            179562 non-null  float64
#  23  TAXI_IN              179562 non-null  float64
#  24  CRS_ARR_TIME         183123 non-null  int64
#  25  ARR_TIME             179562 non-null  float64
#  26  ARR_DELAY            179338 non-null  float64
#  27  ARR_DELAY_NEW        179338 non-null  float64
#  28  ARR_DEL15            179338 non-null  float64
#  29  ARR_DELAY_GROUP      179338 non-null  float64
#  30  ARR_TIME_BLK         183123 non-null  object
#  31  CANCELED             183123 non-null  int64
#  32  CANCELLATION_CODE    3508 non-null    object
#  33  DIVERTED             183123 non-null  int64
#  34  CRS_ELAPSED_TIME     183123 non-null  float64
#  35  ACTUAL_ELAPSED_TIME  179338 non-null  float64
#  36  AIR_TIME             179338 non-null  float64
#  37  DISTANCE             183123 non-null  int64
#  38  CARRIER_DELAY        50555 non-null   float64
#  39  WEATHER_DELAY        50555 non-null   float64
#  40  NAS_DELAY            50555 non-null   float64
#  41  SECURITY_DELAY       50555 non-null   float64
#  42  LATE_AIRCRAFT_DELAY  50555 non-null   float64
#  43  PASSENGERS           182955 non-null  float64
#  44  EMPFULL              182955 non-null  float64
#  45  EMPPART              182955 non-null  float64
#  46  EMPTOTAL             182955 non-null  float64
#  47  EMPFTE               182955 non-null  float64
#  48  NET_INCOME           182955 non-null  float64
#  49  OP_REVENUES          182955 non-null  float64
# dtypes: float64(29), int64(12), object(9)
# memory usage: 69.9+ MB

# %%
df.isna().sum()
# Out:
# YEAR                        0
# QUARTER                     0
# MONTH                       0
# DAY_OF_MONTH                0
# DAY_OF_WEEK                 0
# FL_DATE                     0
# CARRIER                     0
# FL_NUM                      0
# Route                       0
# ORIGIN                      0
# DEST                        0
# DEST_CITY                   0
# DEST_STATE                  0
# CRS_DEP_TIME                0
# DEP_TIME                 3329
# DEP_DELAY                3399
# DEP_DELAY_NEW            3399
# DEP_DEL15                3399
# DEP_DELAY_GROUP          3399
# DEP_TIME_BLK                0
# TAXI_OUT                 3508
# WHEELS_OFF               3507
# WHEELS_ON                3561
# TAXI_IN                  3561
# CRS_ARR_TIME                0
# ARR_TIME                 3561
# ARR_DELAY                3785
# ARR_DELAY_NEW            3785
# ARR_DEL15                3785
# ARR_DELAY_GROUP          3785
# ARR_TIME_BLK                0
# CANCELED                    0
# CANCELLATION_CODE      179615
# DIVERTED                    0
# CRS_ELAPSED_TIME            0
# ACTUAL_ELAPSED_TIME      3785
# AIR_TIME                 3785
# DISTANCE                    0
# CARRIER_DELAY          132568
# WEATHER_DELAY          132568
# NAS_DELAY              132568
# SECURITY_DELAY         132568
# LATE_AIRCRAFT_DELAY    132568
# PASSENGERS                168
# EMPFULL                   168
# EMPPART                   168
# EMPTOTAL                  168
# EMPFTE                    168
# NET_INCOME                168
# OP_REVENUES               168
# dtype: int64

# %%
df=df.dropna(subset=['ARR_DEL15'])

# %%
df['FL_NUM'].nunique()
# Out:
# 1629

# %%
#binary encoding
import category_encoders as ce

encoder = ce.BinaryEncoder(cols=['CARRIER','ORIGIN','DEST','FL_NUM'])
df = encoder.fit_transform(df)

df.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  CARRIER_0  \
# 0  2018        1      1             1            1  2018-01-01          1
# 1  2018        1      1             1            1  2018-01-01          1
# 2  2018        1      1             2            2  2018-01-02          1
# 3  2018        1      1             2            2  2018-01-02          1
# 4  2018        1      1             3            3  2018-01-03          1
#
#    FL_NUM_0  FL_NUM_1  FL_NUM_2  ...  NAS_DELAY  SECURITY_DELAY  \
# 0         0         0         0  ...        NaN             NaN
# 1         0         0         0  ...        NaN             NaN
# 2         0         0         0  ...        NaN             NaN
# 3         0         0         0  ...        NaN             NaN
# 4         0         0         0  ...        NaN             NaN
#
#    LATE_AIRCRAFT_DELAY  PASSENGERS  EMPFULL  EMPPART  EMPTOTAL  EMPFTE  \
# 0                  NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 1                  NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 2                  NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 3                  NaN      3461.0   3706.0     39.0    3745.0  3726.0
# 4                  NaN      3461.0   3706.0     39.0    3745.0  3726.0
#
#    NET_INCOME  OP_REVENUES
# 0    24887.67    464436.41
# 1    24887.67    464436.41
# 2    24887.67    464436.41
# 3    24887.67    464436.41
# 4    24887.67    464436.41
#
# [5 rows x 75 columns]

# %%
df.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'CARRIER_0', 'FL_NUM_0', 'FL_NUM_1', 'FL_NUM_2', 'FL_NUM_3', 'FL_NUM_4',
#        'FL_NUM_5', 'FL_NUM_6', 'FL_NUM_7', 'FL_NUM_8', 'FL_NUM_9', 'FL_NUM_10',
#        'FL_NUM_11', 'Route', 'ORIGIN_0', 'ORIGIN_1', 'ORIGIN_2', 'ORIGIN_3',
#        'ORIGIN_4', 'ORIGIN_5', 'ORIGIN_6', 'ORIGIN_7', 'DEST_0', 'DEST_1',
#        'DEST_2', 'DEST_3', 'DEST_4', 'DEST_5', 'DEST_6', 'DEST_7', 'DEST_CITY',
#        'DEST_STATE', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW',
#        'DEP_DEL15', 'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'TAXI_OUT',
#        'WHEELS_OFF', 'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME',
#        'ARR_DELAY', 'ARR_DELAY_NEW', 'ARR_DEL15', 'ARR_DELAY_GROUP',
#        'ARR_TIME_BLK', 'CANCELED', 'CANCELLATION_CODE', 'DIVERTED',
#        'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'PASSENGERS', 'EMPFULL', 'EMPPART', 'EMPTOTAL',
#        'EMPFTE', 'NET_INCOME', 'OP_REVENUES'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179338 entries, 0 to 183122
# Data columns (total 75 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 179338 non-null  int64
#  1   QUARTER              179338 non-null  int64
#  2   MONTH                179338 non-null  int64
#  3   DAY_OF_MONTH         179338 non-null  int64
#  4   DAY_OF_WEEK          179338 non-null  int64
#  5   FL_DATE              179338 non-null  object
#  6   CARRIER_0            179338 non-null  int64
#  7   FL_NUM_0             179338 non-null  int64
#  8   FL_NUM_1             179338 non-null  int64
#  9   FL_NUM_2             179338 non-null  int64
#  10  FL_NUM_3             179338 non-null  int64
#  11  FL_NUM_4             179338 non-null  int64
#  12  FL_NUM_5             179338 non-null  int64
#  13  FL_NUM_6             179338 non-null  int64
#  14  FL_NUM_7             179338 non-null  int64
#  15  FL_NUM_8             179338 non-null  int64
#  16  FL_NUM_9             179338 non-null  int64
#  17  FL_NUM_10            179338 non-null  int64
#  18  FL_NUM_11            179338 non-null  int64
#  19  Route                179338 non-null  int64
#  20  ORIGIN_0             179338 non-null  int64
#  21  ORIGIN_1             179338 non-null  int64
#  22  ORIGIN_2             179338 non-null  int64
#  23  ORIGIN_3             179338 non-null  int64
#  24  ORIGIN_4             179338 non-null  int64
#  25  ORIGIN_5             179338 non-null  int64
#  26  ORIGIN_6             179338 non-null  int64
#  27  ORIGIN_7             179338 non-null  int64
#  28  DEST_0               179338 non-null  int64
#  29  DEST_1               179338 non-null  int64
#  30  DEST_2               179338 non-null  int64
#  31  DEST_3               179338 non-null  int64
#  32  DEST_4               179338 non-null  int64
#  33  DEST_5               179338 non-null  int64
#  34  DEST_6               179338 non-null  int64
#  35  DEST_7               179338 non-null  int64
#  36  DEST_CITY            179338 non-null  object
#  37  DEST_STATE           179338 non-null  object
#  38  CRS_DEP_TIME         179338 non-null  int64
#  39  DEP_TIME             179338 non-null  float64
#  40  DEP_DELAY            179338 non-null  float64
#  41  DEP_DELAY_NEW        179338 non-null  float64
#  42  DEP_DEL15            179338 non-null  float64
#  43  DEP_DELAY_GROUP      179338 non-null  float64
#  44  DEP_TIME_BLK         179338 non-null  object
#  45  TAXI_OUT             179338 non-null  float64
#  46  WHEELS_OFF           179338 non-null  float64
#  47  WHEELS_ON            179338 non-null  float64
#  48  TAXI_IN              179338 non-null  float64
#  49  CRS_ARR_TIME         179338 non-null  int64
#  50  ARR_TIME             179338 non-null  float64
#  51  ARR_DELAY            179338 non-null  float64
#  52  ARR_DELAY_NEW        179338 non-null  float64
#  53  ARR_DEL15            179338 non-null  float64
#  54  ARR_DELAY_GROUP      179338 non-null  float64
#  55  ARR_TIME_BLK         179338 non-null  object
#  56  CANCELED             179338 non-null  int64
#  57  CANCELLATION_CODE    0 non-null       object
#  58  DIVERTED             179338 non-null  int64
#  59  CRS_ELAPSED_TIME     179338 non-null  float64
#  60  ACTUAL_ELAPSED_TIME  179338 non-null  float64
#  61  AIR_TIME             179338 non-null  float64
#  62  DISTANCE             179338 non-null  int64
#  63  CARRIER_DELAY        50555 non-null   float64
#  64  WEATHER_DELAY        50555 non-null   float64
#  65  NAS_DELAY            50555 non-null   float64
#  66  SECURITY_DELAY       50555 non-null   float64
#  67  LATE_AIRCRAFT_DELAY  50555 non-null   float64
#  68  PASSENGERS           179183 non-null  float64
#  69  EMPFULL              179183 non-null  float64
#  70  EMPPART              179183 non-null  float64
#  71  EMPTOTAL             179183 non-null  float64
#  72  EMPFTE               179183 non-null  float64
#  73  NET_INCOME           179183 non-null  float64
#  74  OP_REVENUES          179183 non-null  float64
# dtypes: float64(29), int64(40), object(6)
# memory usage: 104.0+ MB

# %%
df['CRS_ARR_TIME'].values
# Out:
# array([ 700, 1904,  700, ..., 1252, 1842, 1812], dtype=int64)

# %%
df[['CARRIER_DELAY','LATE_AIRCRAFT_DELAY']].corr()
# Out:
#                      CARRIER_DELAY  LATE_AIRCRAFT_DELAY
# CARRIER_DELAY             1.000000            -0.114067
# LATE_AIRCRAFT_DELAY      -0.114067             1.000000

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df.iloc[:,38] = labelencoder.fit_transform(df.iloc[:,38].values)
df.iloc[:,45] = labelencoder.fit_transform(df.iloc[:,45].values)
df.iloc[:,46] = labelencoder.fit_transform(df.iloc[:,46].values)
df.iloc[:,47] = labelencoder.fit_transform(df.iloc[:,47].values)
df.iloc[:,48] = labelencoder.fit_transform(df.iloc[:,48].values)
df.iloc[:,49] = labelencoder.fit_transform(df.iloc[:,49].values)

# %%
df=df.fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 179338 entries, 0 to 183122
# Data columns (total 75 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   YEAR                 179338 non-null  int64
#  1   QUARTER              179338 non-null  int64
#  2   MONTH                179338 non-null  int64
#  3   DAY_OF_MONTH         179338 non-null  int64
#  4   DAY_OF_WEEK          179338 non-null  int64
#  5   FL_DATE              179338 non-null  object
#  6   CARRIER_0            179338 non-null  int64
#  7   FL_NUM_0             179338 non-null  int64
#  8   FL_NUM_1             179338 non-null  int64
#  9   FL_NUM_2             179338 non-null  int64
#  10  FL_NUM_3             179338 non-null  int64
#  11  FL_NUM_4             179338 non-null  int64
#  12  FL_NUM_5             179338 non-null  int64
#  13  FL_NUM_6             179338 non-null  int64
#  14  FL_NUM_7             179338 non-null  int64
#  15  FL_NUM_8             179338 non-null  int64
#  16  FL_NUM_9             179338 non-null  int64
#  17  FL_NUM_10            179338 non-null  int64
#  18  FL_NUM_11            179338 non-null  int64
#  19  Route                179338 non-null  int64
#  20  ORIGIN_0             179338 non-null  int64
#  21  ORIGIN_1             179338 non-null  int64
#  22  ORIGIN_2             179338 non-null  int64
#  23  ORIGIN_3             179338 non-null  int64
#  24  ORIGIN_4             179338 non-null  int64
#  25  ORIGIN_5             179338 non-null  int64
#  26  ORIGIN_6             179338 non-null  int64
#  27  ORIGIN_7             179338 non-null  int64
#  28  DEST_0               179338 non-null  int64
#  29  DEST_1               179338 non-null  int64
#  30  DEST_2               179338 non-null  int64
#  31  DEST_3               179338 non-null  int64
#  32  DEST_4               179338 non-null  int64
#  33  DEST_5               179338 non-null  int64
#  34  DEST_6               179338 non-null  int64
#  35  DEST_7               179338 non-null  int64
#  36  DEST_CITY            179338 non-null  object
#  37  DEST_STATE           179338 non-null  object
#  38  CRS_DEP_TIME         179338 non-null  int64
#  39  DEP_TIME             179338 non-null  float64
#  40  DEP_DELAY            179338 non-null  float64
#  41  DEP_DELAY_NEW        179338 non-null  float64
#  42  DEP_DEL15            179338 non-null  float64
#  43  DEP_DELAY_GROUP      179338 non-null  float64
#  44  DEP_TIME_BLK         179338 non-null  object
#  45  TAXI_OUT             179338 non-null  int64
#  46  WHEELS_OFF           179338 non-null  int64
#  47  WHEELS_ON            179338 non-null  int64
#  48  TAXI_IN              179338 non-null  int64
#  49  CRS_ARR_TIME         179338 non-null  int64
#  50  ARR_TIME             179338 non-null  float64
#  51  ARR_DELAY            179338 non-null  float64
#  52  ARR_DELAY_NEW        179338 non-null  float64
#  53  ARR_DEL15            179338 non-null  float64
#  54  ARR_DELAY_GROUP      179338 non-null  float64
#  55  ARR_TIME_BLK         179338 non-null  object
#  56  CANCELED             179338 non-null  int64
#  57  CANCELLATION_CODE    179338 non-null  int64
#  58  DIVERTED             179338 non-null  int64
#  59  CRS_ELAPSED_TIME     179338 non-null  float64
#  60  ACTUAL_ELAPSED_TIME  179338 non-null  float64
#  61  AIR_TIME             179338 non-null  float64
#  62  DISTANCE             179338 non-null  int64
#  63  CARRIER_DELAY        179338 non-null  float64
#  64  WEATHER_DELAY        179338 non-null  float64
#  65  NAS_DELAY            179338 non-null  float64
#  66  SECURITY_DELAY       179338 non-null  float64
#  67  LATE_AIRCRAFT_DELAY  179338 non-null  float64
#  68  PASSENGERS           179338 non-null  float64
#  69  EMPFULL              179338 non-null  float64
#  70  EMPPART              179338 non-null  float64
#  71  EMPTOTAL             179338 non-null  float64
#  72  EMPFTE               179338 non-null  float64
#  73  NET_INCOME           179338 non-null  float64
#  74  OP_REVENUES          179338 non-null  float64
# dtypes: float64(25), int64(45), object(5)
# memory usage: 104.0+ MB

# %%
df.columns
# Out:
# Index(['YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'FL_DATE',
#        'CARRIER_0', 'FL_NUM_0', 'FL_NUM_1', 'FL_NUM_2', 'FL_NUM_3', 'FL_NUM_4',
#        'FL_NUM_5', 'FL_NUM_6', 'FL_NUM_7', 'FL_NUM_8', 'FL_NUM_9', 'FL_NUM_10',
#        'FL_NUM_11', 'Route', 'ORIGIN_0', 'ORIGIN_1', 'ORIGIN_2', 'ORIGIN_3',
#        'ORIGIN_4', 'ORIGIN_5', 'ORIGIN_6', 'ORIGIN_7', 'DEST_0', 'DEST_1',
#        'DEST_2', 'DEST_3', 'DEST_4', 'DEST_5', 'DEST_6', 'DEST_7', 'DEST_CITY',
#        'DEST_STATE', 'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'DEP_DELAY_NEW',
#        'DEP_DEL15', 'DEP_DELAY_GROUP', 'DEP_TIME_BLK', 'TAXI_OUT',
#        'WHEELS_OFF', 'WHEELS_ON', 'TAXI_IN', 'CRS_ARR_TIME', 'ARR_TIME',
#        'ARR_DELAY', 'ARR_DELAY_NEW', 'ARR_DEL15', 'ARR_DELAY_GROUP',
#        'ARR_TIME_BLK', 'CANCELED', 'CANCELLATION_CODE', 'DIVERTED',
#        'CRS_ELAPSED_TIME', 'ACTUAL_ELAPSED_TIME', 'AIR_TIME', 'DISTANCE',
#        'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY',
#        'LATE_AIRCRAFT_DELAY', 'PASSENGERS', 'EMPFULL', 'EMPPART', 'EMPTOTAL',
#        'EMPFTE', 'NET_INCOME', 'OP_REVENUES'],
#       dtype='object')

# %%
# Use numpy to convert to arrays
import numpy as np

# Labels are the values we want to predict
labels = np.array(df['ARR_DELAY'])

# Remove the labels from the features
# axis 1 refers to the columns
features= df[[ 'YEAR', 'QUARTER', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK',
       'CARRIER_0', 'FL_NUM_0', 'FL_NUM_1', 'FL_NUM_2', 'FL_NUM_3', 'FL_NUM_4',
       'FL_NUM_5', 'FL_NUM_6', 'FL_NUM_7', 'FL_NUM_8', 'FL_NUM_9', 'FL_NUM_10',
       'FL_NUM_11','ORIGIN_0', 'ORIGIN_1', 'ORIGIN_2', 'ORIGIN_3',
       'ORIGIN_4', 'ORIGIN_5', 'ORIGIN_6', 'ORIGIN_7', 'DEST_0', 'DEST_1',
       'DEST_2', 'DEST_3', 'DEST_4', 'DEST_5', 'DEST_6', 'DEST_7','CRS_DEP_TIME',  'TAXI_OUT',
       'WHEELS_OFF','CRS_ARR_TIME', 'AIR_TIME', 'DISTANCE',
       'PASSENGERS', 'EMPTOTAL',
       'NET_INCOME', 'OP_REVENUES']]

# Saving feature names for later use
feature_list = list(features.columns)

# Convert to numpy array
features = np.array(features)

# %%
df['WHEELS_ON'].values
# Out:
# array([ 409, 1117,  402, ...,  739, 1155, 1180], dtype=int64)

# %%
feature_list
# Out:
# ['YEAR',
#  'QUARTER',
#  'MONTH',
#  'DAY_OF_MONTH',
#  'DAY_OF_WEEK',
#  'CARRIER_0',
#  'FL_NUM_0',
#  'FL_NUM_1',
#  'FL_NUM_2',
#  'FL_NUM_3',
#  'FL_NUM_4',
#  'FL_NUM_5',
#  'FL_NUM_6',
#  'FL_NUM_7',
#  'FL_NUM_8',
#  'FL_NUM_9',
#  'FL_NUM_10',
#  'FL_NUM_11',
#  'Route_0',
#  'Route_1',
#  'Route_2',
#  'Route_3',
#  'Route_4',
#  'Route_5',
#  'Route_6',
#  'Route_7',
#  'Route_8',
#  'Route_9',
#  'Route_10',
#  'ORIGIN_0',
#  'ORIGIN_1',
#  'ORIGIN_2',
#  'ORIGIN_3',
#  'ORIGIN_4',
#  'ORIGIN_5',
#  'ORIGIN_6',
#  'ORIGIN_7',
#  'DEST_0',
#  'DEST_1',
#  'DEST_2',
#  'DEST_3',
#  'DEST_4',
#  'DEST_5',
#  'DEST_6',
#  'DEST_7',
#  'CRS_ARR_TIME',
#  'DISTANCE',
#  'PASSENGERS',
#  'EMPFULL',
#  'EMPPART',
#  'EMPTOTAL',
#  'EMPFTE',
#  'NET_INCOME',
#  'OP_REVENUES',
#  'AIR_TIME']

# %%
labels
# Out:
# array([ -2., -18.,  -9., ..., -25.,  44.,  99.])

# %%
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
import numpy as np
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.model_selection import KFold
import pandas as pd
from sklearn import metrics

# %%
x_train,x_test,y_train,y_test = train_test_split(features,labels,test_size = 0.2)

# %%
import time
from sklearn.ensemble import RandomForestRegressor
start = time.time()
# Instantiate model 
rf_reg = RandomForestRegressor(n_estimators=30)
rf_reg.fit(x_train,y_train)

end = time.time()
print(f"{end-start} seconds")
# Out:
# 288.2900221347809 seconds

# %%
y_pred = rf_reg.predict(x_test)

rsqure_score = rf_reg.score(x_train,y_train)
print('R^2: {}'.format(rsqure_score))
rsqure_testscore = rf_reg.score(x_test,y_test)
print('R^2: {}'.format(rsqure_testscore))
# Out:
# R^2: 0.9915378524766684
# R^2: 0.9462043237936563

# %%
# Get numerical feature importances
importances = list(rf_reg.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 5)) for feature, importance in zip(feature_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: CRS_DEP_TIME         Importance: 0.58884
# Variable: WHEELS_OFF           Importance: 0.30691
# Variable: TAXI_OUT             Importance: 0.03463
# Variable: CRS_ARR_TIME         Importance: 0.01861
# Variable: AIR_TIME             Importance: 0.01366
# Variable: DAY_OF_MONTH         Importance: 0.00476
# Variable: DISTANCE             Importance: 0.00463
# Variable: PASSENGERS           Importance: 0.00455
# Variable: Route                Importance: 0.00352
# Variable: EMPTOTAL             Importance: 0.00263
# Variable: DAY_OF_WEEK          Importance: 0.00237
# Variable: MONTH                Importance: 0.00229
# Variable: NET_INCOME           Importance: 0.00075
# Variable: OP_REVENUES          Importance: 0.00072
# Variable: FL_NUM_11            Importance: 0.0006
# Variable: FL_NUM_4             Importance: 0.00059
# Variable: FL_NUM_1             Importance: 0.00056
# Variable: FL_NUM_7             Importance: 0.00055
# Variable: FL_NUM_3             Importance: 0.00053
# Variable: DEST_7               Importance: 0.00049
# Variable: QUARTER              Importance: 0.00047
# Variable: FL_NUM_10            Importance: 0.00047
# Variable: DEST_5               Importance: 0.00047
# Variable: DEST_6               Importance: 0.00045
# Variable: FL_NUM_9             Importance: 0.00043
# Variable: FL_NUM_8             Importance: 0.00042
# Variable: ORIGIN_4             Importance: 0.00041
# Variable: FL_NUM_6             Importance: 0.0004
# Variable: ORIGIN_3             Importance: 0.0004
# Variable: ORIGIN_7             Importance: 0.0004
# Variable: DEST_3               Importance: 0.0004
# Variable: FL_NUM_2             Importance: 0.00039
# Variable: DEST_4               Importance: 0.00039
# Variable: FL_NUM_5             Importance: 0.00038
# Variable: ORIGIN_6             Importance: 0.00038
# Variable: ORIGIN_5             Importance: 0.00037
# Variable: DEST_2               Importance: 0.00034
# Variable: ORIGIN_1             Importance: 0.00029
# Variable: ORIGIN_2             Importance: 0.00026
# Variable: YEAR                 Importance: 0.00016
# Variable: DEST_1               Importance: 0.00013
# Variable: CARRIER_0            Importance: 0.0
# Variable: FL_NUM_0             Importance: 0.0
# Variable: ORIGIN_0             Importance: 0.0
# Variable: DEST_0               Importance: 0.0

# %% [markdown]
# # Perform the training using K Fold cross validation method

# %%
cv_r2_scores_rf = cross_val_score(rf_reg, features, labels, cv=5,scoring='r2')
print(cv_r2_scores_rf)
print("Mean 5-Fold R Squared: {}".format(np.mean(cv_r2_scores_rf)))
# Out:
# [0.91404375 0.9400968  0.94395323 0.89210975 0.92070549]
# Mean 5-Fold R Squared: 0.9221818043170353

# %%
# Use the forest's predict method on the test data
predictions = rf_reg.predict(x_test)

# Calculate the absolute errors
errors = abs(predictions - y_test)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 8.11 degrees.

# %%
df['FL_NUM_6']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 183118    0
# 183119    0
# 183120    0
# 183121    0
# 183122    0
# Name: FL_NUM_6, Length: 179338, dtype: int64

# %%
df[['PASSENGERS','ARR_DELAY']].corr()
# Out:
#             PASSENGERS  ARR_DELAY
# PASSENGERS    1.000000   0.008391
# ARR_DELAY     0.008391   1.000000
